# %%
import matplotlib.pyplot as plt
import pandas as pd 
# %matplotlib inline

# %%
import numpy as np

# %%
data = np.array ([['25/100','10/30','.269'],['23/100','100/340','.280']])

# %%
column_labels = ['Season 1', 'Season 2','Total BA']
row_labels = ['Player A', 'Player B']

# %%
data
# Out:
# array([['25/100', '10/30', '.269'],
#        ['23/100', '100/340', '.280']], dtype='<U7')

# %%
fig, ax = plt.subplots()

# %%
cell = table[0,0]
cell.set_text_props(text='Hits/Attempts')

# %%
ax.axis('off')
ax.axis('tight')
# Out:
# (np.float64(-0.05500000000000001),
#  np.float64(0.05500000000000001),
#  np.float64(-0.05500000000000001),
#  np.float64(0.05500000000000001))

# %%
table = ax.table(cellText=data,colLabels=column_labels, rowLabels=row_labels)

# %%
table.scale(1, 1.5)
table.auto_set_font_size(False)
table.set_fontsize(12)

# %%
fig.tight_layout()
plt.show()
